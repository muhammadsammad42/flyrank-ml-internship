# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muhammadsammad42/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# ### My Lane: Content Refresh / Content Opportunity Scoring
#
# I chose the **Content Refresh / Content Opportunity Scoring** lane because it focuses on identifying website pages that are most likely to benefit from being updated. Many websites contain hundreds or thousands of pages, making it difficult to decide which pages should be refreshed first. A machine learning model can help prioritize these pages based on their performance and content characteristics, allowing the SEO or content team to focus their efforts where they can have the greatest impact.

# %%
import os, subprocess

REPO_URL = "https://github.com/muhammadsammad42/flyrank-ml-internship.git"
REPO_DIR = "flyrank-ml-internship"

if not os.path.exists(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL], check=True)

os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())
# Out:
# Current directory: /content/flyrank-ml-internship/flyrank-ml-internship

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Ans: The goal of this project is to help the SEO or content team decide which website pages should be refreshed first. Based on the model's recommendations, the team can update content, improve keywords, or rewrite outdated pages to increase traffic and user engagement. A wrong recommendation could cause the team to spend time updating pages that do not need improvement while ignoring pages that are actually declining, leading to missed opportunities and wasted effort.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# Ans: The starter dataset contains **30,000 pages**, providing enough data to analyze content performance. Out of these, **16,262 pages are marked as declining**, showing that a large number of pages may require attention. The average content age is **256.2 days**, suggesting that many pages have existed for a long time and could benefit from being reviewed or refreshed. These observations indicate that prioritizing which pages to update is a meaningful problem, making the Content Refresh lane worth exploring over the next seven weeks.

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Basic statistics
print("Total pages:", len(df))
print("Declining pages:", (df["trend_direction"].str.lower() == "down").sum())
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average content age (days):", round(df["content_age_days"].mean(), 1))
# Out:
# Total pages: 30000
# Declining pages: 16262
# Average CTR: 0.5107
# Average content age (days): 256.2

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# Ans: This project will provide decision-support by identifying pages that appear more likely to benefit from a content refresh based on patterns observed in the available data. The results should be interpreted as observed and directional rather than definitive. It will not prove that refreshing a page causes better rankings or traffic, nor will it predict Google's algorithm or guarantee future search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
